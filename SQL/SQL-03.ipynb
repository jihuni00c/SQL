# %% [markdown]
# - python 데이터 수집 -> mysql 데이터 저장
# - python 라이브러리 모듈 천국
# - pymysql 라이브러리
# - ! -> pip 명령어가 주피터노트북 전용 CLI 명령어 x, 운영체제 터미널
# - !pip -> 주피터노트북 버전 업데이트 pip

# %%
# !pip install pymysql

# %%
import pymysql 

db = pymysql.connect(
    host="localhost",
    port=3306,
    user="root",
    passwd="126845as",
    db="ecommerce",
    charset="utf8mb4"
)

# %%
db

# %%
# 정상적으로 python & mysql 연결
# cursor() 메서드 호출 => Cursor객체 -> mysql DB안에 값을 전송해주는 역할

ecommerce = db.cursor()

# %%
ecommerce

# %%
sql = """
    CREATE TABLE product(
        product_code VARCHAR(20) NOT NULL PRIMARY KEY,
        title VARCHAR(200) NOT NULL,
        ori_price INT,
        discount_price INT,
        discount_percent INT,
        delivery VARCHAR(2)
    );
"""

# %%
ecommerce.execute(sql)
# Out:
# 0

# %%
db.commit()

# %%
db.close()

# %%
for index in range(10):
    product_code = 215673140 + index + 1
    SQL = """INSERT INTO product VALUES('"""+str(product_code)+"""',
    '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', 23000, 6900, 70, 'F'
    );
    """
    print(SQL)
# Out:
# INSERT INTO product VALUES('215673141',
#     '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', 23000, 6900, 70, 'F'
#     );
#
# INSERT INTO product VALUES('215673142',
#     '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', 23000, 6900, 70, 'F'
#     );
#
# INSERT INTO product VALUES('215673143',
#     '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', 23000, 6900, 70, 'F'
#     );
#
# INSERT INTO product VALUES('215673144',
#     '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', 23000, 6900, 70, 'F'
#     );
#
# INSERT INTO product VALUES('215673145',
#     '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', 23000, 6900, 70, 'F'
#     );
#
# INSERT INTO product VALUES('215673146',
#     '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', 23000, 6900, 70, 'F'
#     );
#
# INSERT INTO product VALUES('215673147',
#     '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', 23000, 6900, 70, 'F'
#     );
#
# INSERT INTO product VALUES('215673148',
#     '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', 23000, 6900, 70, 'F'
#     );
#
# INSERT INTO product VALUES('215673149',
# ...

# %%
cursor = db.cursor()

# %%
cursor

# %%
for index in range(10):
    product_code = 215673140 + index + 1
    SQL = f"""INSERT INTO product VALUES('{product_code}',
    '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', 23000, 6900, 70, 'F'
    );
    """
    # print(SQL)
    cursor.execute(SQL)
    
db.commit()

db.close()

# %%
# db를 연결한 후 close() -> 오픈되어있는 db가 종료됨!
# 만약 다시 동일한 db안에 테이블에 접속을 하려면 다시 db connect 해야한다!

# %%
cursor = db.cursor()
SQL = "SELECT * FROM product;"
cursor.execute(SQL)

# row = cursor.fetchone()
row = cursor.fetchmany(2)
print(row)

row = cursor.fetchone()
print(row)

db.close()
# Out:
# (('215673141', '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', 23000, 6900, 70, 'F'), ('215673142', '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', 23000, 6900, 70, 'F'))
# ('215673143', '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', 23000, 6900, 70, 'F')
